# %%
# read the data and set the datetime as the index
import pandas as pd
url = 'https://raw.githubusercontent.com/upxacademy/ML_with_Python/master/Datasets/bikeshare.csv?token=AYxzdiGnjM610dBT7PuwUnUNOmm3bGcvks5ZFDyLwA%3D%3D'
bikes = pd.read_csv(url, index_col='datetime', parse_dates=True)

# %%
bikes
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# ...

# %%
bikes.rename(columns={'count':'total'},inplace=True)

# %%
bikes.head(10)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#                      humidity  windspeed  casual  registered  total
# datetime
# 2011-01-01 00:00:00        81     0.0000       3          13     16
# ...

# %%
bikes.tail(10)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-19 14:00:00       4        0           1        1  17.22  21.210
# 2012-12-19 15:00:00       4        0           1        1  17.22  21.210
# 2012-12-19 16:00:00       4        0           1        1  17.22  21.210
# 2012-12-19 17:00:00       4        0           1        1  16.40  20.455
# 2012-12-19 18:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  total
# datetime
# 2012-12-19 14:00:00        50    12.9980      33         185    218
# ...

# %%
bikes.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['font.size'] = 17

# %%
bikes.plot(kind='scatter',x='season',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter',x='holiday',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter',x='workingday',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter',x='weather',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter',x='temp',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter',x='atemp',y='total',alpha=0.2)

# %%
bikes.plot(kind='scatter', x='humidity', y='total', alpha=0.3)

# %%
bikes.plot(kind='scatter',x='windspeed',y='total',alpha=0.2)

# %%
# Seaborn scatter plot with regression line
sns.lmplot(x='temp', y='total', data=bikes, aspect=1.5, scatter_kws={'alpha':0.3})

# %%
sns.lmplot(x='atemp', y='total', data=bikes, aspect=1.5, scatter_kws={'alpha':0.3})

# %%
sns.lmplot(x='humidity', y='total', data=bikes, aspect=2, scatter_kws={'alpha':0.3})

# %%
# create X and y
feature_cols = ['temp']
X = bikes[feature_cols]
y = bikes['total']# or bikes.total

# %%
X.head(5)
# Out:
#                      temp
# datetime
# 2011-01-01 00:00:00  9.84
# 2011-01-01 01:00:00  9.02
# 2011-01-01 02:00:00  9.02
# 2011-01-01 03:00:00  9.84
# 2011-01-01 04:00:00  9.84

# %%
y.head(5)
# Out:
# datetime
# 2011-01-01 00:00:00    16
# 2011-01-01 01:00:00    40
# 2011-01-01 02:00:00    32
# 2011-01-01 03:00:00    13
# 2011-01-01 04:00:00     1
# Name: total, dtype: int64

# %%
# import, instantiate, fit
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# print the coefficients
print (linreg.intercept_)
print (linreg.coef_)
# Out:
# 6.04621295962
# [ 9.17054048]

# %%
# manually calculate the prediction
linreg.intercept_ + linreg.coef_*25
# Out:
# array([ 235.309725])

# %%
# use the predict method
linreg.predict(25)
# Out:
# array([ 235.309725])

# %%
# create a list of features
feature_cols = ['temp', 'atemp', 'weather', 'humidity']

# %%
# create X and y
X = bikes[feature_cols]
y = bikes.total

# instantiate and fit
linreg = LinearRegression()
linreg.fit(X, y)

# print the coefficients
print (linreg.intercept_)
print (linreg.coef_)
# Out:
# 175.229401551
# [ 2.97335245  5.37459182  4.59198414 -2.86748611]

# %%
# pair the feature names with the coefficients
list(zip(feature_cols, linreg.coef_))
# Out:
# [('temp', 2.9733524466940611),
#  ('atemp', 5.3745918192553441),
#  ('weather', 4.5919841438502065),
#  ('humidity', -2.8674861059969956)]

# %%
# multiple scatter plots in Seaborn
sns.pairplot(bikes, x_vars=feature_cols, y_vars='total', kind='reg')

# %%
# box plot of rentals, grouped by season
bikes.boxplot(column='total', by='season')
# Out:
# C:\Users\Sai Krishna\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:224: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return reshape(newshape, order=order)

# %%
# line plot of rentals
bikes.plot(legend=None)

# %%
# example true and predicted response values
true = [10, 7, 5, 5]
pred = [8, 6, 5, 10]

# %%
# calculate these metrics by hand!
from sklearn import metrics
import numpy as np
print ('MAE:', metrics.mean_absolute_error(true, pred))
print ('MSE:', metrics.mean_squared_error(true, pred))
print ('RMSE:', np.sqrt(metrics.mean_squared_error(true, pred)))
# Out:
# MAE: 2.0
# MSE: 7.5
# RMSE: 2.73861278753

# %%
from sklearn.cross_validation import train_test_split

def train_test_rmse(feature_cols):
    X=bikes[feature_cols]
    y=bikes['total']
    xTrain, xTest, yTrain, yTest = train_test_split(X,y,random_state=3)
    linreg=LinearRegression()
    linreg.fit(xTrain,yTrain)
    y_pred=linreg.predict(xTest)
    return np.sqrt(metrics.mean_squared_error(yTest,y_pred))

# %%
print(train_test_rmse(['temp','season','weather','humidity']))
print(train_test_rmse(['temp','season','humidity']))
print(train_test_rmse(['temp','season','weather']))
# Out:
# 154.206386155
# 154.310651377
# 163.594469014

# %%
print(train_test_rmse(['atemp','humidity','windspeed']))
# Out:
# 155.778325522

# %%
print(train_test_rmse(['atemp','humidity','windspeed','season']))
# Out:
# 154.214950482

# %%
# split X and y into training and testing sets
xTrain, xTest, yTrain, yTest = train_test_split(X, y, random_state=123)

# create a NumPy array with the same shape as y_test
y_null = np.zeros_like(yTest, dtype=float)

# fill the array with the mean value of y_test
y_null.fill(yTest.mean())
y_null
# Out:
# array([ 192.26451139,  192.26451139,  192.26451139, ...,  192.26451139,
#         192.26451139,  192.26451139])

# %%
# compute null RMSE
np.sqrt(metrics.mean_squared_error(yTest, y_null))
# Out:
# 179.57906896465727

# %%
season_dummies=pd.get_dummies(bikes.season,prefix='season')
season_dummies.head()
# Out:
#                      season_1  season_2  season_3  season_4
# datetime
# 2011-01-01 00:00:00         1         0         0         0
# 2011-01-01 01:00:00         1         0         0         0
# 2011-01-01 02:00:00         1         0         0         0
# 2011-01-01 03:00:00         1         0         0         0
# 2011-01-01 04:00:00         1         0         0         0

# %%
season_dummies.drop(season_dummies.columns[0],inplace=True,axis=1)
season_dummies.head()
# Out:
#                      season_2  season_3  season_4
# datetime
# 2011-01-01 00:00:00         0         0         0
# 2011-01-01 01:00:00         0         0         0
# 2011-01-01 02:00:00         0         0         0
# 2011-01-01 03:00:00         0         0         0
# 2011-01-01 04:00:00         0         0         0

# %%
bikes=pd.concat([bikes,season_dummies],axis=1)
bikes.sample(n=5, random_state=1)
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-09-05 11:00:00       3        1           0        2  28.70  33.335
# 2012-03-18 04:00:00       1        0           0        2  17.22  21.210
# 2012-10-14 17:00:00       4        0           0        1  26.24  31.060
# 2011-04-04 15:00:00       2        0           1        1  31.16  33.335
# 2012-12-11 02:00:00       4        0           1        2  16.40  20.455
#
#                      humidity  windspeed  casual  registered  total  season_2  \
# datetime
# 2011-09-05 11:00:00        74    11.0014     101         207    308         0
# 2012-03-18 04:00:00        94    11.0014       6           8     14         0
# 2012-10-14 17:00:00        44    12.9980     193         346    539         0
# 2011-04-04 15:00:00        23    36.9974      47          96    143         1
# 2012-12-11 02:00:00        66    22.0028       0           1      1         0
#
# ...

# %%
# include dummy variables for season in the model
feature_cols = ['temp', 'season_2', 'season_3', 'season_4', 'humidity']
X = bikes[feature_cols]
y = bikes.total
linreg = LinearRegression()
linreg.fit(X, y)
list(zip(feature_cols, linreg.coef_))
# Out:
# [('temp', 11.186405863575786),
#  ('season_2', -3.3905430997179926),
#  ('season_3', -41.736860713170813),
#  ('season_4', 64.415961468242045),
#  ('humidity', -2.8194816362596491)]

# %%
# compare original season variable with dummy variables
print (train_test_rmse(['temp', 'season', 'humidity']))
print(train_test_rmse(['temp','humidity','season_2','season_3','season_4']))
# Out:
# 154.310651377
# 153.371437918

# %%
bikes['hour']=bikes.index.hour
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  total  season_2  \
# datetime
# 2011-01-01 00:00:00        81        0.0       3          13     16         0
# 2011-01-01 01:00:00        80        0.0       8          32     40         0
# 2011-01-01 02:00:00        80        0.0       5          27     32         0
# 2011-01-01 03:00:00        75        0.0       3          10     13         0
# 2011-01-01 04:00:00        75        0.0       0           1      1         0
#
# ...

# %%
hour_dummies=pd.get_dummies(bikes.hour,prefix='hour')
hour_dummies.head()
# Out:
#                      hour_0  hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  \
# datetime
# 2011-01-01 00:00:00       1       0       0       0       0       0       0
# 2011-01-01 01:00:00       0       1       0       0       0       0       0
# 2011-01-01 02:00:00       0       0       1       0       0       0       0
# 2011-01-01 03:00:00       0       0       0       1       0       0       0
# 2011-01-01 04:00:00       0       0       0       0       1       0       0
#
#                      hour_7  hour_8  hour_9   ...     hour_14  hour_15  \
# datetime                                      ...
# 2011-01-01 00:00:00       0       0       0   ...           0        0
# 2011-01-01 01:00:00       0       0       0   ...           0        0
# 2011-01-01 02:00:00       0       0       0   ...           0        0
# 2011-01-01 03:00:00       0       0       0   ...           0        0
# 2011-01-01 04:00:00       0       0       0   ...           0        0
#
# ...

# %%
hour_dummies.drop(hour_dummies.columns[0],axis=1,inplace=True)
hour_dummies.head()
# Out:
#                      hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  hour_7  \
# datetime
# 2011-01-01 00:00:00       0       0       0       0       0       0       0
# 2011-01-01 01:00:00       1       0       0       0       0       0       0
# 2011-01-01 02:00:00       0       1       0       0       0       0       0
# 2011-01-01 03:00:00       0       0       1       0       0       0       0
# 2011-01-01 04:00:00       0       0       0       1       0       0       0
#
#                      hour_8  hour_9  hour_10   ...     hour_14  hour_15  \
# datetime                                       ...
# 2011-01-01 00:00:00       0       0        0   ...           0        0
# 2011-01-01 01:00:00       0       0        0   ...           0        0
# 2011-01-01 02:00:00       0       0        0   ...           0        0
# 2011-01-01 03:00:00       0       0        0   ...           0        0
# 2011-01-01 04:00:00       0       0        0   ...           0        0
#
# ...

# %%
bikes=pd.concat([bikes,hour_dummies],axis=1)
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered   ...     \
# datetime                                                       ...
# 2011-01-01 00:00:00        81        0.0       3          13   ...
# 2011-01-01 01:00:00        80        0.0       8          32   ...
# 2011-01-01 02:00:00        80        0.0       5          27   ...
# 2011-01-01 03:00:00        75        0.0       3          10   ...
# 2011-01-01 04:00:00        75        0.0       0           1   ...
#
# ...

# %%
bikes['daytime']=((bikes.hour > 6) & (bikes.hour < 21)).astype(int)
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered   ...     \
# datetime                                                       ...
# 2011-01-01 00:00:00        81        0.0       3          13   ...
# 2011-01-01 01:00:00        80        0.0       8          32   ...
# 2011-01-01 02:00:00        80        0.0       5          27   ...
# 2011-01-01 03:00:00        75        0.0       3          10   ...
# 2011-01-01 04:00:00        75        0.0       0           1   ...
#
# ...

# %%
print (train_test_rmse(['hour']))
print (train_test_rmse(bikes.columns[bikes.columns.str.startswith('hour_')]))
print (train_test_rmse(['daytime']))
# Out:
# 165.554984135
# 124.072323165
# 144.840228341

# %%
print(train_test_rmse(['daytime','temp','humidity','season_2','season_3','season_4']))
# Out:
# 130.193152596

# %%
print(train_test_rmse(['daytime','temp','humidity','season_2','season_3','season_4','hour_1','hour_2','hour_3','hour_4','hour_5','hour_6','hour_7','hour_8','hour_9','hour_10','hour_11','hour_12','hour_13','hour_14','hour_15','hour_16','hour_17','hour_18','hour_19','hour_20','hour_21','hour_22','hour_23']))
# Out:
# 110.304716903

# %%
print(train_test_rmse(['workingday','daytime','temp','humidity','season_2','season_3','season_4','hour_1','hour_2','hour_3','hour_4','hour_5','hour_6','hour_7','hour_8','hour_9','hour_10','hour_11','hour_12','hour_13','hour_14','hour_15','hour_16','hour_17','hour_18','hour_19','hour_20','hour_21','hour_22','hour_23']))
# Out:
# 110.324337287

# %%
print(train_test_rmse(['holiday','daytime','temp','humidity','season_2','season_3','season_4','hour_1','hour_2','hour_3','hour_4','hour_5','hour_6','hour_7','hour_8','hour_9','hour_10','hour_11','hour_12','hour_13','hour_14','hour_15','hour_16','hour_17','hour_18','hour_19','hour_20','hour_21','hour_22','hour_23']))
# Out:
# 110.296876509

# %%
weather_dummies=pd.get_dummies(bikes['weather'],prefix='weather')
weather_dummies.head()
# Out:
#                      weather_1  weather_2  weather_3  weather_4
# datetime
# 2011-01-01 00:00:00          1          0          0          0
# 2011-01-01 01:00:00          1          0          0          0
# 2011-01-01 02:00:00          1          0          0          0
# 2011-01-01 03:00:00          1          0          0          0
# 2011-01-01 04:00:00          1          0          0          0

# %%
weather_dummies.drop(weather_dummies.columns[0],axis=1,inplace=True)
weather_dummies.head()
# Out:
#                      weather_2  weather_3  weather_4
# datetime
# 2011-01-01 00:00:00          0          0          0
# 2011-01-01 01:00:00          0          0          0
# 2011-01-01 02:00:00          0          0          0
# 2011-01-01 03:00:00          0          0          0
# 2011-01-01 04:00:00          0          0          0

# %%
bikes=pd.concat([bikes,weather_dummies],axis=1)
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered    ...      \
# datetime                                                        ...
# 2011-01-01 00:00:00        81        0.0       3          13    ...
# 2011-01-01 01:00:00        80        0.0       8          32    ...
# 2011-01-01 02:00:00        80        0.0       5          27    ...
# 2011-01-01 03:00:00        75        0.0       3          10    ...
# 2011-01-01 04:00:00        75        0.0       0           1    ...
#
# ...

# %%
print(train_test_rmse(['weather_2','weather_3','weather_4','holiday','daytime','temp','humidity','season_2','season_3','season_4','hour_1','hour_2','hour_3','hour_4','hour_5','hour_6','hour_7','hour_8','hour_9','hour_10','hour_11','hour_12','hour_13','hour_14','hour_15','hour_16','hour_17','hour_18','hour_19','hour_20','hour_21','hour_22','hour_23']))
# Out:
# 717588007134.0

# %%
humidity_dummies=pd.get_dummies(bikes.humidity,prefix='humidity')
humidity_dummies.head()
# Out:
#                      humidity_0  humidity_8  humidity_10  humidity_12  \
# datetime
# 2011-01-01 00:00:00           0           0            0            0
# 2011-01-01 01:00:00           0           0            0            0
# 2011-01-01 02:00:00           0           0            0            0
# 2011-01-01 03:00:00           0           0            0            0
# 2011-01-01 04:00:00           0           0            0            0
#
#                      humidity_13  humidity_14  humidity_15  humidity_16  \
# datetime
# 2011-01-01 00:00:00            0            0            0            0
# 2011-01-01 01:00:00            0            0            0            0
# 2011-01-01 02:00:00            0            0            0            0
# 2011-01-01 03:00:00            0            0            0            0
# 2011-01-01 04:00:00            0            0            0            0
#
#                      humidity_17  humidity_18      ...       humidity_88  \
# ...

# %%
humidity_dummies.drop(humidity_dummies.columns[0],axis=1,inplace=True)
humidity_dummies.head()
# Out:
#                      humidity_8  humidity_10  humidity_12  humidity_13  \
# datetime
# 2011-01-01 00:00:00           0            0            0            0
# 2011-01-01 01:00:00           0            0            0            0
# 2011-01-01 02:00:00           0            0            0            0
# 2011-01-01 03:00:00           0            0            0            0
# 2011-01-01 04:00:00           0            0            0            0
#
#                      humidity_14  humidity_15  humidity_16  humidity_17  \
# datetime
# 2011-01-01 00:00:00            0            0            0            0
# 2011-01-01 01:00:00            0            0            0            0
# 2011-01-01 02:00:00            0            0            0            0
# 2011-01-01 03:00:00            0            0            0            0
# 2011-01-01 04:00:00            0            0            0            0
#
#                      humidity_18  humidity_19      ...       humidity_88  \
# ...

# %%
bikes=pd.concat([bikes,humidity_dummies],axis=1)
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered      ...       \
# datetime                                                          ...
# 2011-01-01 00:00:00        81        0.0       3          13      ...
# 2011-01-01 01:00:00        80        0.0       8          32      ...
# 2011-01-01 02:00:00        80        0.0       5          27      ...
# 2011-01-01 03:00:00        75        0.0       3          10      ...
# 2011-01-01 04:00:00        75        0.0       0           1      ...
#
# ...

# %%
humidity_cols=humidity_dummies.columns
humidity_cols
# Out:
# Index(['humidity_8', 'humidity_10', 'humidity_12', 'humidity_13',
#        'humidity_14', 'humidity_15', 'humidity_16', 'humidity_17',
#        'humidity_18', 'humidity_19', 'humidity_20', 'humidity_21',
#        'humidity_22', 'humidity_23', 'humidity_24', 'humidity_25',
#        'humidity_26', 'humidity_27', 'humidity_28', 'humidity_29',
#        'humidity_30', 'humidity_31', 'humidity_32', 'humidity_33',
#        'humidity_34', 'humidity_35', 'humidity_36', 'humidity_37',
#        'humidity_38', 'humidity_39', 'humidity_40', 'humidity_41',
#        'humidity_42', 'humidity_43', 'humidity_44', 'humidity_45',
#        'humidity_46', 'humidity_47', 'humidity_48', 'humidity_49',
#        'humidity_50', 'humidity_51', 'humidity_52', 'humidity_53',
#        'humidity_54', 'humidity_55', 'humidity_56', 'humidity_57',
#        'humidity_58', 'humidity_59', 'humidity_60', 'humidity_61',
#        'humidity_62', 'humidity_63', 'humidity_64', 'humidity_65',
# ...

# %%
hour_cols=hour_dummies.columns
hour_cols
# Out:
# Index(['hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
#        'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
#        'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
#        'hour_20', 'hour_21', 'hour_22', 'hour_23'],
#       dtype='object')

# %%
print(train_test_rmse(['temp','holiday','daytime','season_2','season_3','season_4','hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
       'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
       'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
       'hour_20', 'hour_21', 'hour_22', 'hour_23','humidity_8', 'humidity_10', 'humidity_12', 'humidity_13',
       'humidity_14', 'humidity_15', 'humidity_16', 'humidity_17',
       'humidity_18', 'humidity_19', 'humidity_20', 'humidity_21',
       'humidity_22', 'humidity_23', 'humidity_24', 'humidity_25',
       'humidity_26', 'humidity_27', 'humidity_28', 'humidity_29',
       'humidity_30', 'humidity_31', 'humidity_32', 'humidity_33',
       'humidity_34', 'humidity_35', 'humidity_36', 'humidity_37',
       'humidity_38', 'humidity_39', 'humidity_40', 'humidity_41',
       'humidity_42', 'humidity_43', 'humidity_44', 'humidity_45',
       'humidity_46', 'humidity_47', 'humidity_48', 'humidity_49',
       'humidity_50', 'humidity_51', 'humidity_52', 'humidity_53',
       'humidity_54', 'humidity_55', 'humidity_56', 'humidity_57',
       'humidity_58', 'humidity_59', 'humidity_60', 'humidity_61',
       'humidity_62', 'humidity_63', 'humidity_64', 'humidity_65',
       'humidity_66', 'humidity_67', 'humidity_68', 'humidity_69',
       'humidity_70', 'humidity_71', 'humidity_72', 'humidity_73',
       'humidity_74', 'humidity_75', 'humidity_76', 'humidity_77',
       'humidity_78', 'humidity_79', 'humidity_80', 'humidity_81',
       'humidity_82', 'humidity_83', 'humidity_84', 'humidity_85',
       'humidity_86', 'humidity_87', 'humidity_88', 'humidity_89',
       'humidity_90', 'humidity_91', 'humidity_92', 'humidity_93',
       'humidity_94', 'humidity_96', 'humidity_97', 'humidity_100']))
# Out:
# 109.897366171

# %%
bikes['wind_speed']=bikes['windspeed'].astype(int)
bikes.tail()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered     ...      \
# datetime                                                         ...
# 2012-12-19 19:00:00        50    26.0027       7         329     ...
# 2012-12-19 20:00:00        57    15.0013      10         231     ...
# 2012-12-19 21:00:00        61    15.0013       4         164     ...
# 2012-12-19 22:00:00        61     6.0032      12         117     ...
# 2012-12-19 23:00:00        66     8.9981       4          84     ...
#
# ...

# %%
wind_dummies=pd.get_dummies(bikes['wind_speed'],prefix='windspeed')
wind_dummies.head()
# Out:
#                      windspeed_0  windspeed_6  windspeed_7  windspeed_8  \
# datetime
# 2011-01-01 00:00:00            1            0            0            0
# 2011-01-01 01:00:00            1            0            0            0
# 2011-01-01 02:00:00            1            0            0            0
# 2011-01-01 03:00:00            1            0            0            0
# 2011-01-01 04:00:00            1            0            0            0
#
#                      windspeed_11  windspeed_12  windspeed_15  windspeed_16  \
# datetime
# 2011-01-01 00:00:00             0             0             0             0
# 2011-01-01 01:00:00             0             0             0             0
# 2011-01-01 02:00:00             0             0             0             0
# 2011-01-01 03:00:00             0             0             0             0
# 2011-01-01 04:00:00             0             0             0             0
#
# ...

# %%
wind_dummies.drop(wind_dummies.columns[0],axis=1,inplace=True)
wind_dummies.head()
# Out:
#                      windspeed_6  windspeed_7  windspeed_8  windspeed_11  \
# datetime
# 2011-01-01 00:00:00            0            0            0             0
# 2011-01-01 01:00:00            0            0            0             0
# 2011-01-01 02:00:00            0            0            0             0
# 2011-01-01 03:00:00            0            0            0             0
# 2011-01-01 04:00:00            0            0            0             0
#
#                      windspeed_12  windspeed_15  windspeed_16  windspeed_19  \
# datetime
# 2011-01-01 00:00:00             0             0             0             0
# 2011-01-01 01:00:00             0             0             0             0
# 2011-01-01 02:00:00             0             0             0             0
# 2011-01-01 03:00:00             0             0             0             0
# 2011-01-01 04:00:00             0             0             0             0
#
# ...

# %%
bikes=pd.concat([bikes,wind_dummies],axis=1)
bikes.tail()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered      ...       \
# datetime                                                          ...
# 2012-12-19 19:00:00        50    26.0027       7         329      ...
# 2012-12-19 20:00:00        57    15.0013      10         231      ...
# 2012-12-19 21:00:00        61    15.0013       4         164      ...
# 2012-12-19 22:00:00        61     6.0032      12         117      ...
# 2012-12-19 23:00:00        66     8.9981       4          84      ...
#
# ...

# %%
windspeed_cols=wind_dummies.columns
windspeed_cols
# Out:
# Index(['windspeed_6', 'windspeed_7', 'windspeed_8', 'windspeed_11',
#        'windspeed_12', 'windspeed_15', 'windspeed_16', 'windspeed_19',
#        'windspeed_22', 'windspeed_23', 'windspeed_26', 'windspeed_27',
#        'windspeed_30', 'windspeed_31', 'windspeed_32', 'windspeed_35',
#        'windspeed_36', 'windspeed_39', 'windspeed_40', 'windspeed_43',
#        'windspeed_46', 'windspeed_47', 'windspeed_50', 'windspeed_51',
#        'windspeed_56'],
#       dtype='object')

# %%
print(train_test_rmse(['temp','holiday','daytime','season_2','season_3','season_4','hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
       'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
       'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
       'hour_20', 'hour_21', 'hour_22', 'hour_23','humidity_8', 'humidity_10', 'humidity_12', 'humidity_13',
       'humidity_14', 'humidity_15', 'humidity_16', 'humidity_17',
       'humidity_18', 'humidity_19', 'humidity_20', 'humidity_21',
       'humidity_22', 'humidity_23', 'humidity_24', 'humidity_25',
       'humidity_26', 'humidity_27', 'humidity_28', 'humidity_29',
       'humidity_30', 'humidity_31', 'humidity_32', 'humidity_33',
       'humidity_34', 'humidity_35', 'humidity_36', 'humidity_37',
       'humidity_38', 'humidity_39', 'humidity_40', 'humidity_41',
       'humidity_42', 'humidity_43', 'humidity_44', 'humidity_45',
       'humidity_46', 'humidity_47', 'humidity_48', 'humidity_49',
       'humidity_50', 'humidity_51', 'humidity_52', 'humidity_53',
       'humidity_54', 'humidity_55', 'humidity_56', 'humidity_57',
       'humidity_58', 'humidity_59', 'humidity_60', 'humidity_61',
       'humidity_62', 'humidity_63', 'humidity_64', 'humidity_65',
       'humidity_66', 'humidity_67', 'humidity_68', 'humidity_69',
       'humidity_70', 'humidity_71', 'humidity_72', 'humidity_73',
       'humidity_74', 'humidity_75', 'humidity_76', 'humidity_77',
       'humidity_78', 'humidity_79', 'humidity_80', 'humidity_81',
       'humidity_82', 'humidity_83', 'humidity_84', 'humidity_85',
       'humidity_86', 'humidity_87', 'humidity_88', 'humidity_89',
       'humidity_90', 'humidity_91', 'humidity_92', 'humidity_93',
       'humidity_94', 'humidity_96', 'humidity_97', 'humidity_100','windspeed_6', 'windspeed_7', 'windspeed_8', 'windspeed_11',
       'windspeed_12', 'windspeed_15', 'windspeed_16', 'windspeed_19',
       'windspeed_22', 'windspeed_23', 'windspeed_26', 'windspeed_27',
       'windspeed_30', 'windspeed_31', 'windspeed_32', 'windspeed_35',
       'windspeed_36', 'windspeed_39', 'windspeed_40', 'windspeed_43',
       'windspeed_46', 'windspeed_47', 'windspeed_50', 'windspeed_51',
       'windspeed_56']))
# Out:
# 109.731866232

# %%
print(train_test_rmse(['temp','holiday','workingday','season_2','season_3','season_4','hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
       'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
       'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
       'hour_20', 'hour_21', 'hour_22', 'hour_23','humidity_8', 'humidity_10', 'humidity_12', 'humidity_13',
       'humidity_14', 'humidity_15', 'humidity_16', 'humidity_17',
       'humidity_18', 'humidity_19', 'humidity_20', 'humidity_21',
       'humidity_22', 'humidity_23', 'humidity_24', 'humidity_25',
       'humidity_26', 'humidity_27', 'humidity_28', 'humidity_29',
       'humidity_30', 'humidity_31', 'humidity_32', 'humidity_33',
       'humidity_34', 'humidity_35', 'humidity_36', 'humidity_37',
       'humidity_38', 'humidity_39', 'humidity_40', 'humidity_41',
       'humidity_42', 'humidity_43', 'humidity_44', 'humidity_45',
       'humidity_46', 'humidity_47', 'humidity_48', 'humidity_49',
       'humidity_50', 'humidity_51', 'humidity_52', 'humidity_53',
       'humidity_54', 'humidity_55', 'humidity_56', 'humidity_57',
       'humidity_58', 'humidity_59', 'humidity_60', 'humidity_61',
       'humidity_62', 'humidity_63', 'humidity_64', 'humidity_65',
       'humidity_66', 'humidity_67', 'humidity_68', 'humidity_69',
       'humidity_70', 'humidity_71', 'humidity_72', 'humidity_73',
       'humidity_74', 'humidity_75', 'humidity_76', 'humidity_77',
       'humidity_78', 'humidity_79', 'humidity_80', 'humidity_81',
       'humidity_82', 'humidity_83', 'humidity_84', 'humidity_85',
       'humidity_86', 'humidity_87', 'humidity_88', 'humidity_89',
       'humidity_90', 'humidity_91', 'humidity_92', 'humidity_93',
       'humidity_94', 'humidity_96', 'humidity_97', 'humidity_100','windspeed_6', 'windspeed_7', 'windspeed_8', 'windspeed_11',
       'windspeed_12', 'windspeed_15', 'windspeed_16', 'windspeed_19',
       'windspeed_22', 'windspeed_23', 'windspeed_26', 'windspeed_27',
       'windspeed_30', 'windspeed_31', 'windspeed_32', 'windspeed_35',
       'windspeed_36', 'windspeed_39', 'windspeed_40', 'windspeed_43',
       'windspeed_46', 'windspeed_47', 'windspeed_50', 'windspeed_51',
       'windspeed_56']))
# Out:
# 109.736248769

# %%
bikes['day']=bikes.index.day
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered ...   \
# datetime                                                     ...
# 2011-01-01 00:00:00        81        0.0       3          13 ...
# 2011-01-01 01:00:00        80        0.0       8          32 ...
# 2011-01-01 02:00:00        80        0.0       5          27 ...
# 2011-01-01 03:00:00        75        0.0       3          10 ...
# 2011-01-01 04:00:00        75        0.0       0           1 ...
#
# ...

# %%
day_dummies=pd.get_dummies(bikes.day,prefix='day')
day_dummies.head()
# Out:
#                      day_1  day_2  day_3  day_4  day_5  day_6  day_7  day_8  \
# datetime
# 2011-01-01 00:00:00      1      0      0      0      0      0      0      0
# 2011-01-01 01:00:00      1      0      0      0      0      0      0      0
# 2011-01-01 02:00:00      1      0      0      0      0      0      0      0
# 2011-01-01 03:00:00      1      0      0      0      0      0      0      0
# 2011-01-01 04:00:00      1      0      0      0      0      0      0      0
#
#                      day_9  day_10  day_11  day_12  day_13  day_14  day_15  \
# datetime
# 2011-01-01 00:00:00      0       0       0       0       0       0       0
# 2011-01-01 01:00:00      0       0       0       0       0       0       0
# 2011-01-01 02:00:00      0       0       0       0       0       0       0
# 2011-01-01 03:00:00      0       0       0       0       0       0       0
# 2011-01-01 04:00:00      0       0       0       0       0       0       0
#
# ...

# %%
day_dummies.drop(day_dummies.columns[0],axis=1,inplace=True)
bikes=pd.concat([bikes,day_dummies],axis=1)
bikes.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered   ...    day_10  \
# datetime                                                       ...
# 2011-01-01 00:00:00        81        0.0       3          13   ...         0
# 2011-01-01 01:00:00        80        0.0       8          32   ...         0
# 2011-01-01 02:00:00        80        0.0       5          27   ...         0
# 2011-01-01 03:00:00        75        0.0       3          10   ...         0
# ...

# %%
day_cols=day_dummies.columns
day_cols
# Out:
# Index(['day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7', 'day_8', 'day_9',
#        'day_10', 'day_11', 'day_12', 'day_13', 'day_14', 'day_15', 'day_16',
#        'day_17', 'day_18', 'day_19'],
#       dtype='object')

# %%
print(train_test_rmse(['temp','daytime','holiday','workingday','season_2','season_3','season_4','hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
       'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
       'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
       'hour_20', 'hour_21', 'hour_22', 'hour_23','humidity_8', 'humidity_10', 'humidity_12', 'humidity_13',
       'humidity_14', 'humidity_15', 'humidity_16', 'humidity_17',
       'humidity_18', 'humidity_19', 'humidity_20', 'humidity_21',
       'humidity_22', 'humidity_23', 'humidity_24', 'humidity_25',
       'humidity_26', 'humidity_27', 'humidity_28', 'humidity_29',
       'humidity_30', 'humidity_31', 'humidity_32', 'humidity_33',
       'humidity_34', 'humidity_35', 'humidity_36', 'humidity_37',
       'humidity_38', 'humidity_39', 'humidity_40', 'humidity_41',
       'humidity_42', 'humidity_43', 'humidity_44', 'humidity_45',
       'humidity_46', 'humidity_47', 'humidity_48', 'humidity_49',
       'humidity_50', 'humidity_51', 'humidity_52', 'humidity_53',
       'humidity_54', 'humidity_55', 'humidity_56', 'humidity_57',
       'humidity_58', 'humidity_59', 'humidity_60', 'humidity_61',
       'humidity_62', 'humidity_63', 'humidity_64', 'humidity_65',
       'humidity_66', 'humidity_67', 'humidity_68', 'humidity_69',
       'humidity_70', 'humidity_71', 'humidity_72', 'humidity_73',
       'humidity_74', 'humidity_75', 'humidity_76', 'humidity_77',
       'humidity_78', 'humidity_79', 'humidity_80', 'humidity_81',
       'humidity_82', 'humidity_83', 'humidity_84', 'humidity_85',
       'humidity_86', 'humidity_87', 'humidity_88', 'humidity_89',
       'humidity_90', 'humidity_91', 'humidity_92', 'humidity_93',
       'humidity_94', 'humidity_96', 'humidity_97', 'humidity_100','windspeed_6', 'windspeed_7', 'windspeed_8', 'windspeed_11',
       'windspeed_12', 'windspeed_15', 'windspeed_16', 'windspeed_19',
       'windspeed_22', 'windspeed_23', 'windspeed_26', 'windspeed_27',
       'windspeed_30', 'windspeed_31', 'windspeed_32', 'windspeed_35',
       'windspeed_36', 'windspeed_39', 'windspeed_40', 'windspeed_43',
       'windspeed_46', 'windspeed_47', 'windspeed_50', 'windspeed_51',
       'windspeed_56','day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'day_7', 'day_8', 'day_9',
       'day_10', 'day_11', 'day_12', 'day_13', 'day_14', 'day_15', 'day_16',
       'day_17', 'day_18', 'day_19']))
# Out:
# 109.796491052
